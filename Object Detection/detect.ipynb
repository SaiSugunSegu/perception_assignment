# %%
from ultralytics import YOLO

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sFmhUuyFRzH58YlgJkzf")
project = rf.workspace("sugun-segu-6mcs1").project("detect-pallets-and-forklift-from-factory")
dataset = project.version(1).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.160, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to Detect-Pallets-and-forklift-from-factory-1 in yolov8:: 100%|██████████| 50/50 [00:00<00:00, 5524.78it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.0.161 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.160 🚀 Python-3.11.4 torch-2.0.1 CPU (Apple M2)
# ...

# %%
# !yolo task=detect mode=predict model=/Users/naimisha/work/dataset/train/weights/best.pt conf=0.25 source={dataset.location}/test/images show=True
# Out:
# Ultralytics YOLOv8.0.160 🚀 Python-3.11.4 torch-2.0.1 CPU (Apple M2)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# image 1/2 /Users/naimisha/work/dataset/Detect-Pallets-and-forklift-from-factory-1/test/images/Screencast-from-08-23-2023-03_14_34-PM_mp4-13_jpg.rf.6366bae96bd85f9063aefdfed75eb19e.jpg: 800x800 4 Pallets-and-forkliftss, 1 forlift, 458.3ms
# image 2/2 /Users/naimisha/work/dataset/Detect-Pallets-and-forklift-from-factory-1/test/images/Screencast-from-08-23-2023-03_14_34-PM_mp4-6_jpg.rf.a62981cbc764b2123fbf035a4a065da8.jpg: 800x800 8 Pallets-and-forkliftss, 1 forlift, 548.5ms
# Speed: 10.7ms preprocess, 503.4ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict4

# %%
# Load a model
model = YOLO('/Users/naimisha/work/dataset/train/weights/best.pt')  # load a custom model
results = model('/Users/naimisha/work/dataset/train/val_batch0_labels.jpg', conf=0.3, show = True, save=False)  # predict on an image
# Out:
# image 1/1 /Users/naimisha/work/dataset/train/val_batch0_labels.jpg: 800x800 5 Pallets-and-forkliftss, 324.7ms
# Speed: 6.9ms preprocess, 324.7ms inference, 3.2ms postprocess per image at shape (1, 3, 800, 800)
